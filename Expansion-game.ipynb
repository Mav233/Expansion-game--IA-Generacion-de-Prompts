# %%
import google.generativeai as genai
import os

# Configurar API Key
API_KEY = "AIzaSyDD3MoLUFYrarcfH-fmGWJDqS12wofqlTk"
os.environ["GOOGLE_API_KEY"] = API_KEY

genai.configure(api_key=API_KEY)

productos = [
    {"id": 1, "name": "Mouse Logitech G Pro", "price": 80549.99},
    {"id": 2, "name": "Teclado Corsair K55 RGB", "price": 130489.99},
    {"id": 3, "name": "Webcam Logitech C920", "price": 42789.99},
    {"id": 19, "name": "Procesador AMD Ryzen 9 5900X", "price": 408589.99},
    {"id": 20, "name": "Procesador AMD Ryzen 7 5800X", "price": 468166.99},
    {"id": 25, "name": "Tarjeta Gráfica MSI Ventus 3X OC", "price": 515946.99},
    {"id": 26, "name": "Tarjeta Gráfica Zotac Gaming Twin Edge", "price": 467889.99}
]

def generate_response(prompt):
    try:
        model = genai.GenerativeModel("gemini-pro")
        res = model.generate_content(prompt)
        return res.text if res else "No se recibió respuesta."
    except Exception as e:
        return f"Error en la generación de contenido: {e}"

# Mostrar listado de productos
print("Lista de productos disponibles:")
for p in productos:
    print(f"{p['id']}. {p['name']} - ${p['price']:.2f}")

# Interacción con el usuario
uso = input("¿Para qué usarás tu PC y cuál es tu presupuesto en pesos argentinos?: ")
prompt_inicial = f"{uso}. Genera 10 configuraciones de PC gamer: 5 dentro del presupuesto y 5 por debajo, indicando la gama (baja, media o alta)."
print("\nRecomendaciones de configuración:")
print(generate_response(prompt_inicial))

compatibilidad_check = input("\n¿Quieres verificar la compatibilidad de los componentes seleccionados? (si/no): ")
if compatibilidad_check.lower() == "si":
    componentes = input("Lista los componentes seleccionados (separa por comas): ")
    prompt_compatibilidad = f"Estos son los componentes seleccionados: {componentes}. ¿Hay alguna incompatibilidad técnica que deba considerar?"
    print("\nVerificación de compatibilidad:")
    print(generate_response(prompt_compatibilidad))

comparacion_check = input("\n¿Quieres comparar dos productos? (si/no): ")
if comparacion_check.lower() == "si":
    id1 = int(input("Ingresa el ID del primer producto: "))
    id2 = int(input("Ingresa el ID del segundo producto: "))
    prod1 = next((p for p in productos if p['id'] == id1), None)
    prod2 = next((p for p in productos if p['id'] == id2), None)
    if prod1 and prod2:
        prompt_comparacion = f"Compara estos productos: {prod1['name']} (${prod1['price']:.2f}) VS {prod2['name']} (${prod2['price']:.2f}). ¿Cuál es mejor y por qué?"
        print("\nComparación de productos:")
        print(generate_response(prompt_comparacion))
    else:
        print("Uno o ambos productos no fueron encontrados.")

optimizacion_check = input("\n¿Quieres optimizar la configuración para gaming a 1440p? (si/no): ")
if optimizacion_check.lower() == "si":
    prompt_optimizacion = "Con el presupuesto disponible, ¿cuál es la mejor configuración posible para gaming a 1440p?"
    print("\nOptimización de configuración:")
    print(generate_response(prompt_optimizacion))

consulta_check = input("\n¿Tienes alguna consulta técnica? (si/no): ")
if consulta_check.lower() == "si":
    consulta = input("Escribe tu pregunta técnica: ")
    print("\nConsulta técnica:")
    print(generate_response(consulta))
# Out:
# Lista de productos disponibles:
# 1. Mouse Logitech G Pro - $80549.99
# 2. Teclado Corsair K55 RGB - $130489.99
# 3. Webcam Logitech C920 - $42789.99
# 19. Procesador AMD Ryzen 9 5900X - $408589.99
# 20. Procesador AMD Ryzen 7 5800X - $468166.99
# 25. Tarjeta Gráfica MSI Ventus 3X OC - $515946.99
# 26. Tarjeta Gráfica Zotac Gaming Twin Edge - $467889.99
# ¿Para qué usarás tu PC y cuál es tu presupuesto en pesos argentinos?:  10000000
# Recomendaciones de configuración:
# **Dentro del presupuesto (baja)**
#
# 1. Procesador: Intel Core i3-12100F
# 2. Tarjeta gráfica: NVIDIA GeForce GTX 1650
# 3. RAM: 8GB DDR4-3200
# 4. Almacenamiento: SSD NVMe de 256GB
# 5. Fuente de alimentación: 550W 80+ Bronze
# 6. Caja: Phanteks Eclipse P300A
# 7. Precio: Alrededor de $500
#
# 2. Procesador: AMD Ryzen 5 5600G (con gráficos integrados)
# 3. Tarjeta gráfica: Ninguna (utiliza gráficos integrados)
# 4. RAM: 16GB DDR4-3200
# 5. Almacenamiento: SSD NVMe de 512GB
# 6. Fuente de alimentación: 450W 80+ White
# 7. Caja: Cooler Master MasterBox Q30L
# 8. Precio: Alrededor de $450
#
# 3. Procesador: Intel Core i5-11400F
# 4. Tarjeta gráfica: NVIDIA GeForce GTX 1660 Super
# 5. RAM: 16GB DDR4-3600
# 6. Almacenamiento: SSD NVMe de 1TB
# 7. Fuente de alimentación: 650W 80+ Gold
# 8. Caja: Fractal Design Focus 2
# 9. Precio: Alrededor de $650
#
# 4. Procesador: AMD Ryzen 7 5700X
# 5. Tarjeta gráfica: NVIDIA GeForce RTX 3060
# 6. RAM: 32GB DDR4-3600
# 7. Almacenamiento: SSD NVMe de 2TB
# 8. Fuente de alimentación: 750W 80+ Gold
# 9. Caja: NZXT H510 Flow
# 10. Precio: Alrededor de $800
#
# 5. Procesador: Intel Core i9-12900K
# 6. Tarjeta gráfica: NVIDIA GeForce RTX 3070 Ti
# 7. RAM: 64GB DDR5-4800
# 8. Almacenamiento: SSD NVMe de 4TB
# 9. Fuente de alimentación: 1000W 80+ Platinum
# 10. Caja: Lian Li Lancool III
# 11. Precio: Alrededor de $1200
#
# **Por debajo del presupuesto (media)**
#
# 1. Procesador: AMD Ryzen 5 5600X
# 2. Tarjeta gráfica: NVIDIA GeForce RTX 3060 Ti
# 3. RAM: 16GB DDR4-3600
# 4. Almacenamiento: SSD NVMe de 1TB
# 5. Fuente de alimentación: 650W 80+ Gold
# 6. Caja: Corsair 4000D Airflow
# 7. Precio: Alrededor de $1000
#
# 2. Procesador: Intel Core i7-12700K
# 3. Tarjeta gráfica: NVIDIA GeForce RTX 3080
# 4. RAM: 32GB DDR4-3600
# 5. Almacenamiento: SSD NVMe de 2TB
# 6. Fuente de alimentación: 750W 80+ Gold
# 7. Caja: NZXT H7 Flow
# 8. Precio: Alrededor de $1400
#
# 3. Procesador: AMD Ryzen 9 5900X
# 4. Tarjeta gráfica: NVIDIA GeForce RTX 3080 Ti
# 5. RAM: 64GB DDR4-3600
# 6. Almacenamiento: SSD NVMe de 4TB
# 7. Fuente de alimentación: 850W 80+ Platinum
# 8. Caja: Fractal Design Define R6
# 9. Precio: Alrededor de $1800
#
# 4. Procesador: Intel Core i9-12900KS
# 5. Tarjeta gráfica: NVIDIA GeForce RTX 3090
# 6. RAM: 128GB DDR5-4800
# 7. Almacenamiento: SSD NVMe de 8TB
# 8. Fuente de alimentación: 1200W 80+ Platinum
# 9. Caja: Lian Li O11 Dynamic XL
# 10. Precio: Alrededor de $2500
#
# 5. Procesador: AMD Ryzen Threadripper PRO 5995WX
# 6. Tarjeta gráfica: NVIDIA GeForce RTX 3090 Ti
# 7. RAM: 256GB DDR4-3600
# 8. Almacenamiento: SSD NVMe de 16TB
# 9. Fuente de alimentación: 1600W 80+ Platinum
# 10. Caja: Corsair Obsidian 1000D
# 11. Precio: Alrededor de $4000
# ¿Quieres verificar la compatibilidad de los componentes seleccionados? (si/no):  s
#
# ¿Quieres comparar dos productos? (si/no):  si
# Ingresa el ID del primer producto:  1
# Ingresa el ID del segundo producto:  2
# Comparación de productos:
# **Mouse Logitech G Pro**
#
# * Precio: $80549.99
# * Características:
#     * Sensor HERO de última generación con hasta 16.000 DPI
#     * 6 botones programables
#     * Diseño ergonómico para diestros
#     * Pies de PTFE para un deslizamiento suave
#
# **Teclado Corsair K55 RGB**
#
# * Precio: $130489.99
# * Características:
#     * Interruptores de membrana duraderos
#     * 6 teclas macro dedicadas
#     * Iluminación RGB personalizable de 3 zonas
#     * Reposamuñecas desmontable
#
# **Comparación**
#
# **Precio:** El teclado Corsair K55 RGB es significativamente más caro que el mouse Logitech G Pro.
#
# **Características:**
#
# * **Sensor:** El Logitech G Pro Mouse tiene un sensor más avanzado con un DPI máximo más alto.
# * **Botones:** El Logitech G Pro Mouse tiene menos botones programables que el Corsair K55 RGB.
# * **Ergonomía:** El Logitech G Pro Mouse está diseñado ergonómicamente para diestros, mientras que el Corsair K55 RGB no es ergonómico.
# * **Iluminación:** El Corsair K55 RGB tiene iluminación RGB personalizable, mientras que el Logitech G Pro Mouse no la tiene.
# * **Reposamuñecas:** El Corsair K55 RGB incluye un reposamuñecas desmontable, mientras que el Logitech G Pro Mouse no.
#
# **Mejor opción:**
#
# La mejor opción depende de tus necesidades y preferencias específicas.
#
# * **Para juegos competitivos:** El Logitech G Pro Mouse es la mejor opción debido a su sensor más avanzado y diseño ergonómico.
# * **Para uso general:** El Corsair K55 RGB es la mejor opción debido a sus teclas macro adicionales, iluminación RGB y reposamuñecas.
#
# En general, el Logitech G Pro Mouse es un mouse de juego de alta gama con características excelentes, mientras que el Corsair K55 RGB es un teclado más versátil adecuado para juegos y uso general.
# ¿Quieres optimizar la configuración para gaming a 1440p? (si/no):  si
# Optimización de configuración:
# **Procesador:**
#
# * AMD Ryzen 7 7700X o Intel Core i7-13700K
#
# **Tarjeta gráfica:**
#
# * NVIDIA GeForce RTX 4070 Ti o AMD Radeon RX 7900 XTX
#
# **Memoria RAM:**
#
# * 32 GB de DDR5-6000
#
# **Placa base:**
#
# * AM5 para AMD o LGA 1700 para Intel
#
# **SSD:**
#
# * SSD NVMe PCIe 4.0 de 1 TB
#
# **Fuente de alimentación:**
#
# * 850 W o más, con certificación 80+ Gold o superior
#
# **Monitor:**
#
# * Monitor de juegos de 1440p con una frecuencia de actualización de 144 Hz o más, tiempo de respuesta de 1 ms o menos y soporte HDR
#
# **Coste estimado:**
#
# Entre 1.500 y 2.000 dólares
#
# **Configuración detallada:**
#
# * **Procesador:** AMD Ryzen 7 7700X (300-350 dólares) o Intel Core i7-13700K (400-450 dólares)
# * **Tarjeta gráfica:** NVIDIA GeForce RTX 4070 Ti (800-900 dólares) o AMD Radeon RX 7900 XTX (950-1050 dólares)
# * **Memoria RAM:** 32 GB (2x16 GB) DDR5-6000 (200-250 dólares)
# * **Placa base:** MSI Pro X670-P WiFi (250-300 dólares) o ASUS ROG Strix Z790-A Gaming WiFi (280-330 dólares)
# * **SSD:** Samsung 980 Pro 1TB (120-150 dólares)
# * **Fuente de alimentación:** Seasonic Focus GX-850 (120-150 dólares)
# * **Monitor:** Dell S2721DGF (300-350 dólares) o MSI Optix MPG341CQR (500-550 dólares)
#
# Esta configuración proporcionará un excelente rendimiento para juegos a 1440p con altas velocidades de cuadro y gráficos detallados. La tarjeta gráfica y el procesador son lo suficientemente potentes como para manejar incluso los juegos más exigentes, mientras que la memoria RAM y el SSD garantizan cargas rápidas y un juego fluido. El monitor completará la configuración con una imagen nítida, colores precisos y una frecuencia de actualización suave.
# ¿Tienes alguna consulta técnica? (si/no):  si
# Escribe tu pregunta técnica:  para que sirve la placa madre?
# Consulta técnica:
# La placa madre, también conocida como motherboard, es el componente central de una computadora y cumple varias funciones esenciales:
#
# * **Conexión de componentes:** Sirve como interfaz de conexión física entre todos los componentes principales de la computadora, como el procesador, la memoria RAM, las tarjetas gráficas, los dispositivos de almacenamiento y las unidades periféricas.
#
# * **Control y comunicación:** Proporciona vías de comunicación entre los diferentes componentes al alojar buses y chips puente que permiten el intercambio de datos y señales.
#
# * **Suministro de energía:** Distribuye energía eléctrica a todos los componentes conectados. La placa madre tiene un regulador de voltaje que convierte la energía de la fuente de alimentación a los voltajes requeridos por los distintos componentes.
#
# * **Configuración de BIOS:** Almacena y carga el sistema básico de entrada y salida (BIOS), que contiene la configuración y las instrucciones básicas necesarias para que la computadora arranque y funcione correctamente.
#
# * **Expansión:** Permite la expansión del sistema mediante ranuras PCI Express, puertos USB y otros conectores que permiten conectar tarjetas de expansión, como tarjetas gráficas, tarjetas de sonido y tarjetas de red.
#
# * **Montaje:** Proporciona una base física sobre la que se montan y conectan todos los componentes. Sirve como estructura de soporte para todo el sistema.
#
# En resumen, la placa madre es el centro neurálgico de una computadora que conecta, controla, alimenta y configura todos los componentes para garantizar un funcionamiento eficiente y fiable.
